# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.
#
# ## Install the Azure Machine Learning SDK
#
# The Azure Machine Learning SDK is updated frequently. Run the following cell to upgrade to the latest release, along with the additional package to support notebook widgets.

# %%
# !pip install --upgrade azureml-sdk azureml-widgets
# Out:
# Requirement already satisfied: azureml-sdk in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (1.57.0)
# Requirement already satisfied: azureml-widgets in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (1.57.0)
# Requirement already satisfied: azureml-pipeline~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-sdk) (1.57.0)
# Requirement already satisfied: azureml-dataset-runtime[fuse]~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-sdk) (1.57.0)
# Requirement already satisfied: azureml-train-core~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-sdk) (1.57.0)
# Requirement already satisfied: azureml-train-automl-client~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-sdk) (1.57.0)
# Requirement already satisfied: azureml-core~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-sdk) (1.57.0)
# Requirement already satisfied: azure-storage-blob>=12.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-widgets) (12.19.0)
# Requirement already satisfied: ipywidgets<8.0.0,>=7.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-widgets) (7.7.1)
# Requirement already satisfied: jinja2<4.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-widgets) (3.1.4)
# Requirement already satisfied: azureml-telemetry~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-widgets) (1.57.0)
# Requirement already satisfied: isodate>=0.6.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (0.6.1)
# Requirement already satisfied: cryptography>=2.1.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (38.0.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (4.12.2)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-storage-blob>=12.6.0->azureml-widgets) (1.30.2)
# Requirement already satisfied: SecretStorage<4.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (3.3.3)
# Requirement already satisfied: pytz in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (2022.5)
# Requirement already satisfied: adal<=1.2.7,>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (1.2.7)
# Requirement already satisfied: azure-mgmt-containerregistry<11,>=8.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (10.3.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (0.60.0)
# Requirement already satisfied: packaging<=25.0,>=20.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (24.1)
# Requirement already satisfied: docker<8.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (7.1.0)
# Requirement already satisfied: msal<2.0.0,>=1.15.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (1.30.0)
# Requirement already satisfied: pkginfo in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (1.11.1)
# Requirement already satisfied: pyopenssl<25.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (23.0.0)
# Requirement already satisfied: paramiko<4.0.0,>=2.0.8 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (3.4.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.7.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (2.9.0.post0)
# Requirement already satisfied: urllib3<3.0.0,>1.26.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (1.26.19)
# Requirement already satisfied: msal-extensions<=2.0.0,>=0.3.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (1.2.0)
# Requirement already satisfied: azure-mgmt-network<=26.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (25.1.0)
# Requirement already satisfied: jsonpickle<4.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (3.2.2)
# Requirement already satisfied: PyJWT<3.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (2.4.0)
# Requirement already satisfied: msrestazure<=0.7,>=0.4.33 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (0.6.4.post1)
# Requirement already satisfied: azure-mgmt-resource<=24.0.0,>=15.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (23.1.1)
# Requirement already satisfied: jmespath<2.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (0.10.0)
# Requirement already satisfied: ndg-httpsclient<=0.5.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (0.5.1)
# Requirement already satisfied: azure-mgmt-storage<=22.0.0,>=16.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (21.2.0)
# Requirement already satisfied: pathspec<1.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (0.12.1)
# Requirement already satisfied: azure-mgmt-keyvault<11.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (10.3.0)
# Requirement already satisfied: argcomplete<4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (3.3.0)
# Requirement already satisfied: azure-common<2.0.0,>=1.1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (1.1.28)
# Requirement already satisfied: msrest<=0.7.1,>=0.5.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (0.7.1)
# Requirement already satisfied: azure-mgmt-authorization<5,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (4.0.0)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (1.0)
# Requirement already satisfied: humanfriendly<11.0,>=4.7 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (10.0)
# Requirement already satisfied: knack<0.12.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (0.11.0)
# Requirement already satisfied: requests[socks]<3.0.0,>=2.19.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (2.32.3)
# Requirement already satisfied: contextlib2<22.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-core~=1.57.0->azureml-sdk) (21.6.0)
# Requirement already satisfied: numpy!=1.19.3,<1.24 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (1.23.5)
# Requirement already satisfied: pyarrow>=0.17.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (14.0.2)
# Requirement already satisfied: azureml-dataprep<5.2.0a,>=5.1.0a in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (5.1.6)
# Requirement already satisfied: fusepy<4.0.0,>=3.0.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (3.0.1)
# Requirement already satisfied: azureml-pipeline-steps~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-pipeline~=1.57.0->azureml-sdk) (1.57.0)
# Requirement already satisfied: azureml-pipeline-core~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-pipeline~=1.57.0->azureml-sdk) (1.57.0)
# Requirement already satisfied: applicationinsights in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-telemetry~=1.57.0->azureml-widgets) (0.11.10)
# Requirement already satisfied: azureml-automl-core~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-train-automl-client~=1.57.0->azureml-sdk) (1.57.0)
# Requirement already satisfied: azureml-train-restclients-hyperdrive~=1.57.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-train-core~=1.57.0->azureml-sdk) (1.57.0)
# Requirement already satisfied: traitlets>=4.3.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.14.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.29.5)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.1.9)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.6.8)
# Requirement already satisfied: ipython>=4.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (8.27.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jinja2<4.0->azureml-widgets) (2.1.5)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob>=12.6.0->azureml-widgets) (1.16.0)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.3.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.57.0->azureml-sdk) (1.4.0)
# Requirement already satisfied: importlib-resources<=6.4.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-automl-core~=1.57.0->azureml-train-automl-client~=1.57.0->azureml-sdk) (6.4.0)
# Requirement already satisfied: importlib-metadata<=8.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-automl-core~=1.57.0->azureml-train-automl-client~=1.57.0->azureml-sdk) (8.0.0)
# Requirement already satisfied: azureml-dataprep-rslex~=2.22.2dev0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (2.22.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (6.0.1)
# Requirement already satisfied: azureml-dataprep-native<42.0.0,>=41.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (41.0.0)
# Requirement already satisfied: azure-identity>=1.7.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (1.17.1)
# Requirement already satisfied: jsonschema in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (4.23.0)
# Requirement already satisfied: cloudpickle<3.0.0,>=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (2.2.1)
# Requirement already satisfied: cffi>=1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.6.0->azureml-widgets) (1.16.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.7.2)
# Requirement already satisfied: pyzmq>=24 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (26.2.0)
# Requirement already satisfied: nest-asyncio in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.8.5)
# Requirement already satisfied: psutil in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.9.8)
# Requirement already satisfied: tornado>=6.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.4.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (7.4.9)
# Requirement already satisfied: comm>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.1.7)
# Requirement already satisfied: stack-data in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.6.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.0.47)
# Requirement already satisfied: jedi>=0.16 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.18.0)
# Requirement already satisfied: exceptiongroup in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.9.0)
# Requirement already satisfied: decorator in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.18.0)
# Requirement already satisfied: tabulate in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from knack<0.12.0->azureml-core~=1.57.0->azureml-sdk) (0.9.0)
# Requirement already satisfied: portalocker<3,>=1.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msal-extensions<=2.0.0,>=0.3.0->azureml-core~=1.57.0->azureml-sdk) (2.10.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.57.0->azureml-sdk) (2024.8.30)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.57.0->azureml-sdk) (2.0.0)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from ndg-httpsclient<=0.5.1->azureml-core~=1.57.0->azureml-sdk) (0.6.0)
# Requirement already satisfied: pynacl>=1.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.57.0->azureml-sdk) (1.5.0)
# Requirement already satisfied: bcrypt>=3.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.57.0->azureml-sdk) (4.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->azureml-sdk) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->azureml-sdk) (3.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->azureml-sdk) (1.7.1)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from SecretStorage<4.0.0->azureml-core~=1.57.0->azureml-sdk) (0.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.5.7)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from backports.tempfile->azureml-core~=1.57.0->azureml-sdk) (1.0.post1)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.6.0->azureml-widgets) (2.22)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from importlib-metadata<=8.2.0->azureml-automl-core~=1.57.0->azureml-train-automl-client~=1.57.0->azureml-sdk) (3.20.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.8.4)
# Requirement already satisfied: entrypoints in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.3.6)
# Requirement already satisfied: nbconvert>=5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (7.16.4)
# Requirement already satisfied: terminado>=0.8.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.18.1)
# Requirement already satisfied: argon2-cffi in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (23.1.0)
# Requirement already satisfied: prometheus-client in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.21.0)
# Requirement already satisfied: nbformat in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (5.10.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.8.3)
# Requirement already satisfied: nbclassic>=0.4.7 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.7.0)
# Requirement already satisfied: wcwidth in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.13)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core~=1.57.0->azureml-sdk) (3.2.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (0.20.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (0.35.1)
# Requirement already satisfied: attrs>=22.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (24.2.0)
# Requirement already satisfied: pure-eval in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.4.1)
# Requirement already satisfied: notebook-shim>=0.2.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.2.4)
# Requirement already satisfied: nbclient>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.10.0)
# Requirement already satisfied: bleach!=5.0.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (6.1.0)
# Requirement already satisfied: beautifulsoup4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.12.3)
# Requirement already satisfied: tinycss2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.3.0)
# Requirement already satisfied: defusedxml in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.7.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (3.0.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.5.1)
# Requirement already satisfied: jupyterlab-pygments in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.20.0)
# Requirement already satisfied: argon2-cffi-bindings in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (21.2.0)
# Requirement already satisfied: webencodings in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.5.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.14.2)
# Requirement already satisfied: soupsieve>1.2 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.5)
# Requirement already satisfied: websocket-client>=1.7 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.8.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.10.0)
# Requirement already satisfied: anyio>=3.1.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (4.6.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (7.7.0)
# Requirement already satisfied: sniffio>=1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (2.0.7)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.1.1)
# Requirement already satisfied: rfc3339-validator in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.0.0->azureml-widgets) (0.1.4)
# Requirement already satisfied: webcolors>=24.6.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (24.8.0)
# Requirement already satisfied: fqdn in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (1.5.1)
# Requirement already satisfied: isoduration in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (3.0.0)
# Requirement already satisfied: uri-template in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (1.3.0)
# Requirement already satisfied: arrow>=0.15.0 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from isoduration->jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /anaconda/envs/azureml_py38/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema->azureml-dataprep<5.2.0a,>=5.1.0a->azureml-dataset-runtime[fuse]~=1.57.0->azureml-sdk) (2.9.0.20240906)

# %% [markdown]
# ## Connect to your workspace
#
# With the latest version of the SDK installed, now you're ready to connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.57.0 to work with coursera

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.889
# AUC: 0.8746430170655255
# Model trained and registered.
# /tmp/ipykernel_4249/2140859650.py:34: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   run.log('Accuracy', np.float(acc))
# /tmp/ipykernel_4249/2140859650.py:40: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   run.log('AUC', np.float(auc))

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# azureml_globaldatasets - Default = False
# workspacefilestore - Default = False
# workspaceartifactstore - Default = False
# workspaceworkingdirectory - Default = False
# workspaceblobstore - Default = True
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data/1.csv
# Uploaded batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading batch-data/10.csv
# Uploaded batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading batch-data/100.csv
# Uploaded batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading batch-data/11.csv
# Uploaded batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading batch-data/12.csv
# Uploaded batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading batch-data/13.csv
# Uploaded batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading batch-data/14.csv
# Uploaded batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading batch-data/15.csv
# Uploaded batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading batch-data/16.csv
# Uploaded batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading batch-data/17.csv
# Uploaded batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading batch-data/18.csv
# Uploaded batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading batch-data/19.csv
# Uploaded batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading batch-data/2.csv
# Uploaded batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading batch-data/20.csv
# Uploaded batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading batch-data/21.csv
# Uploaded batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading batch-data/22.csv
# Uploaded batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading batch-data/23.csv
# Uploaded batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading batch-data/24.csv
# Uploaded batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading batch-data/25.csv
# Uploaded batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading batch-data/26.csv
# Uploaded batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading batch-data/27.csv
# Uploaded batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading batch-data/28.csv
# Uploaded batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading batch-data/29.csv
# Uploaded batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading batch-data/3.csv
# Uploaded batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading batch-data/30.csv
# Uploaded batch-data/30.csv, 25 files out of an estimated total of 100
# Uploading batch-data/31.csv
# Uploaded batch-data/31.csv, 26 files out of an estimated total of 100
# Uploading batch-data/32.csv
# Uploaded batch-data/32.csv, 27 files out of an estimated total of 100
# Uploading batch-data/33.csv
# Uploaded batch-data/33.csv, 28 files out of an estimated total of 100
# Uploading batch-data/34.csv
# Uploaded batch-data/34.csv, 29 files out of an estimated total of 100
# Uploading batch-data/35.csv
# Uploaded batch-data/35.csv, 30 files out of an estimated total of 100
# Uploading batch-data/36.csv
# Uploaded batch-data/36.csv, 31 files out of an estimated total of 100
# Uploading batch-data/37.csv
# Uploaded batch-data/37.csv, 32 files out of an estimated total of 100
# Uploading batch-data/38.csv
# Uploaded batch-data/38.csv, 33 files out of an estimated total of 100
# Uploading batch-data/39.csv
# Uploaded batch-data/39.csv, 34 files out of an estimated total of 100
# Uploading batch-data/4.csv
# Uploaded batch-data/4.csv, 35 files out of an estimated total of 100
# Uploading batch-data/40.csv
# Uploaded batch-data/40.csv, 36 files out of an estimated total of 100
# Uploading batch-data/41.csv
# Uploaded batch-data/41.csv, 37 files out of an estimated total of 100
# Uploading batch-data/42.csv
# Uploaded batch-data/42.csv, 38 files out of an estimated total of 100
# Uploading batch-data/43.csv
# Uploaded batch-data/43.csv, 39 files out of an estimated total of 100
# Uploading batch-data/44.csv
# Uploaded batch-data/44.csv, 40 files out of an estimated total of 100
# Uploading batch-data/45.csv
# Uploaded batch-data/45.csv, 41 files out of an estimated total of 100
# Uploading batch-data/46.csv
# Uploaded batch-data/46.csv, 42 files out of an estimated total of 100
# Uploading batch-data/47.csv
# Uploaded batch-data/47.csv, 43 files out of an estimated total of 100
# Uploading batch-data/48.csv
# Uploaded batch-data/48.csv, 44 files out of an estimated total of 100
# Uploading batch-data/49.csv
# Uploaded batch-data/49.csv, 45 files out of an estimated total of 100
# Uploading batch-data/5.csv
# Uploaded batch-data/5.csv, 46 files out of an estimated total of 100
# Uploading batch-data/50.csv
# Uploaded batch-data/50.csv, 47 files out of an estimated total of 100
# Uploading batch-data/51.csv
# Uploaded batch-data/51.csv, 48 files out of an estimated total of 100
# Uploading batch-data/52.csv
# Uploaded batch-data/52.csv, 49 files out of an estimated total of 100
# Uploading batch-data/53.csv
# Uploaded batch-data/53.csv, 50 files out of an estimated total of 100
# Uploading batch-data/54.csv
# Uploaded batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading batch-data/55.csv
# Uploaded batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading batch-data/56.csv
# Uploaded batch-data/56.csv, 53 files out of an estimated total of 100
# Uploading batch-data/57.csv
# Uploaded batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading batch-data/58.csv
# Uploaded batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading batch-data/59.csv
# Uploaded batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading batch-data/6.csv
# Uploaded batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading batch-data/60.csv
# Uploaded batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading batch-data/61.csv
# Uploaded batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading batch-data/63.csv
# Uploaded batch-data/63.csv, 60 files out of an estimated total of 100
# Uploading batch-data/64.csv
# Uploaded batch-data/64.csv, 61 files out of an estimated total of 100
# Uploading batch-data/62.csv
# Uploaded batch-data/62.csv, 62 files out of an estimated total of 100
# Uploading batch-data/65.csv
# Uploaded batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading batch-data/66.csv
# Uploaded batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading batch-data/67.csv
# Uploaded batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading batch-data/68.csv
# Uploaded batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading batch-data/69.csv
# Uploaded batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading batch-data/7.csv
# Uploaded batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading batch-data/70.csv
# Uploaded batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading batch-data/71.csv
# Uploaded batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading batch-data/72.csv
# Uploaded batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading batch-data/73.csv
# Uploaded batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading batch-data/74.csv
# Uploaded batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading batch-data/75.csv
# Uploaded batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading batch-data/76.csv
# Uploaded batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading batch-data/77.csv
# Uploaded batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading batch-data/78.csv
# Uploaded batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading batch-data/79.csv
# Uploaded batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading batch-data/8.csv
# Uploaded batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading batch-data/80.csv
# Uploaded batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading batch-data/81.csv
# Uploaded batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading batch-data/82.csv
# Uploaded batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading batch-data/83.csv
# Uploaded batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading batch-data/84.csv
# Uploaded batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading batch-data/85.csv
# Uploaded batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading batch-data/86.csv
# Uploaded batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading batch-data/87.csv
# Uploaded batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading batch-data/88.csv
# Uploaded batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading batch-data/89.csv
# Uploaded batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading batch-data/9.csv
# Uploaded batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading batch-data/90.csv
# Uploaded batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading batch-data/91.csv
# Uploaded batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading batch-data/92.csv
# Uploaded batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading batch-data/93.csv
# Uploaded batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading batch-data/94.csv
# Uploaded batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading batch-data/95.csv
# Uploaded batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading batch-data/96.csv
# Uploaded batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading batch-data/97.csv
# Uploaded batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading batch-data/98.csv
# Uploaded batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading batch-data/99.csv
# Uploaded batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!
# "Datastore.upload" is deprecated after version 1.0.69. Please use "Dataset.File.upload_directory" to upload your files             from a local directory and create FileDataset in single method call. See Dataset API change notice at https://aka.ms/dataset-deprecation.

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "your-compute-cluster"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# InProgress...
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# Next we'll define a run context that includes the dependencies required by the script

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core.runconfig import CondaDependencies

# Add dependencies required by the model
# For scikit-learn models, you need scikit-learn
# For parallel pipeline steps, you need azureml-core and azureml-dataprep[fuse]
cd = CondaDependencies.create(conda_packages=['scikit-learn','pip'],
                              pip_packages=['azureml-defaults','azureml-core','azureml-dataprep[fuse]'])

batch_env = Environment(name='batch_environment')
batch_env.python.conda_dependencies = cd
batch_env.docker.enabled = True
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import PipelineData

default_ds = ws.get_default_datastore()

output_dir = PipelineData(name='inferences', 
                          datastore=default_ds, 
                          output_path_on_compute='diabetes/results')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [202486e3][8de0a783-7cf8-4d94-898c-3c52cf15ec81], (This step will run and generate new outputs)
# Submitted PipelineRun 58abc9c3-6dd9-4a02-a4cd-eeb6d2369615
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/58abc9c3-6dd9-4a02-a4cd-eeb6d2369615?wsid=/subscriptions/69c8f7e5-d34a-43ca-8fc8-17cce3dd848d/resourcegroups/saifahmed.k-rg/workspaces/coursera&tid=44f1ecac-984f-479a-8b55-63bb294261f6
# PipelineRunId: 58abc9c3-6dd9-4a02-a4cd-eeb6d2369615
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/58abc9c3-6dd9-4a02-a4cd-eeb6d2369615?wsid=/subscriptions/69c8f7e5-d34a-43ca-8fc8-17cce3dd848d/resourcegroups/saifahmed.k-rg/workspaces/coursera&tid=44f1ecac-984f-479a-8b55-63bb294261f6
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 51e79426-47cb-473b-aef9-bc8f1c2f6b8e
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/51e79426-47cb-473b-aef9-bc8f1c2f6b8e?wsid=/subscriptions/69c8f7e5-d34a-43ca-8fc8-17cce3dd848d/resourcegroups/saifahmed.k-rg/workspaces/coursera&tid=44f1ecac-984f-479a-8b55-63bb294261f6
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# ======Starting Image Build on Serverless Compute======
# The run ID for the image build on serverless compute is imgbldrun_11bb9a3
# Additional logs for the run: https://ml.azure.com/experiments/id/prepare_image/runs/imgbldrun_11bb9a3?wsid=/subscriptions/69c8f7e5-d34a-43ca-8fc8-17cce3dd848d/resourcegroups/saifahmed.k-rg/workspaces/Coursera&tid=44f1ecac-984f-479a-8b55-63bb294261f6
# 2024-10-13T17:19:51: Logging into Docker registry: fbff0866df0b44e6ad41a794abec9d1a.azurecr.io
# 2024-10-13T17:19:51: WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# 2024-10-13T17:19:51: WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# 2024-10-13T17:19:51: Configure a credential helper to remove this warning. See
# 2024-10-13T17:19:51: https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# 2024-10-13T17:19:51: Login Succeeded
#
#
# 2024-10-13T17:19:51: Running: ['docker', 'build', '-f', 'azureml-environment-setup/Dockerfile', '.', '-t', 'fbff0866df0b44e6ad41a794abec9d1a.azurecr.io/azureml/azureml_1840c4ac9110c49f4bdf862d3ba689d1', '-t', 'fbff0866df0b44e6ad41a794abec9d1a.azurecr.io/azureml/azureml_1840c4ac9110c49f4bdf862d3ba689d1:1']
# 2024-10-13T17:19:51: DEPRECATED: The legacy builder is deprecated and will be removed in a future release.
# 2024-10-13T17:19:51:             Install the buildx component to build images with BuildKit:
# 2024-10-13T17:19:51:             https://docs.docker.com/go/buildx/
#
# 2024-10-13T17:19:51: Sending build context to Docker daemon  71.17kB
# 2024-10-13T17:19:51: Step 1/17 : FROM mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20240709.v1@sha256:19edf62d80807b1b49d667d2008b0ad73190ee956c63d497f2603b8448029c6d
# 2024-10-13T17:19:51: mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20240709.v1@sha256:19edf62d80807b1b49d667d2008b0ad73190ee956c63d497f2603b8448029c6d: Pulling from azureml/openmpi4.1.0-ubuntu20.04
# 2024-10-13T17:19:51: 560c024910be: Pulling fs layer
# 2024-10-13T17:19:51: d087c15fca2d: Pulling fs layer
# 2024-10-13T17:19:51: 8185149f39b5: Pulling fs layer
# 2024-10-13T17:19:51: cba7cfa5f2c4: Pulling fs layer
# 2024-10-13T17:19:51: 38521da1e13b: Pulling fs layer
# 2024-10-13T17:19:51: 01c69afbe599: Pulling fs layer
# 2024-10-13T17:19:51: 97bfe6231c39: Pulling fs layer
# 2024-10-13T17:19:51: d433a81f70e3: Pulling fs layer
# 2024-10-13T17:19:51: a0f1c015153b: Pulling fs layer
# 2024-10-13T17:19:51: 3b1987910610: Pulling fs layer
# 2024-10-13T17:19:51: 97bfe6231c39: Waiting
# 2024-10-13T17:19:51: d433a81f70e3: Waiting
# 2024-10-13T17:19:51: a0f1c015153b: Waiting
# 2024-10-13T17:19:51: 3b1987910610: Waiting
# 2024-10-13T17:19:51: cba7cfa5f2c4: Waiting
# 2024-10-13T17:19:51: 38521da1e13b: Waiting
# 2024-10-13T17:19:51: 01c69afbe599: Waiting
# 2024-10-13T17:19:51: 8185149f39b5: Verifying Checksum
# 2024-10-13T17:19:51: 8185149f39b5: Download complete
# 2024-10-13T17:19:51: cba7cfa5f2c4: Verifying Checksum
# 2024-10-13T17:19:51: cba7cfa5f2c4: Download complete
# 2024-10-13T17:19:51: 560c024910be: Verifying Checksum
# 2024-10-13T17:19:51: 560c024910be: Download complete
# 2024-10-13T17:19:51: 38521da1e13b: Verifying Checksum
# 2024-10-13T17:19:51: 38521da1e13b: Download complete
# 2024-10-13T17:19:52: 97bfe6231c39: Verifying Checksum
# 2024-10-13T17:19:52: 97bfe6231c39: Download complete
# 2024-10-13T17:19:52: d433a81f70e3: Verifying Checksum
# 2024-10-13T17:19:52: d433a81f70e3: Download complete
# 2024-10-13T17:19:52: 01c69afbe599: Verifying Checksum
# 2024-10-13T17:19:52: 01c69afbe599: Download complete
# 2024-10-13T17:19:52: a0f1c015153b: Verifying Checksum
# 2024-10-13T17:19:52: a0f1c015153b: Download complete
# 2024-10-13T17:19:52: 3b1987910610: Verifying Checksum
# 2024-10-13T17:19:52: 3b1987910610: Download complete
# 2024-10-13T17:19:52: d087c15fca2d: Verifying Checksum
# 2024-10-13T17:19:52: d087c15fca2d: Download complete
# 2024-10-13T17:19:53: 560c024910be: Pull complete
# 2024-10-13T17:20:03: d087c15fca2d: Pull complete
# 2024-10-13T17:20:03: 8185149f39b5: Pull complete
# 2024-10-13T17:20:03: cba7cfa5f2c4: Pull complete
# 2024-10-13T17:20:03: 38521da1e13b: Pull complete
# 2024-10-13T17:20:09: 01c69afbe599: Pull complete
# 2024-10-13T17:20:09: 97bfe6231c39: Pull complete
# 2024-10-13T17:20:10: d433a81f70e3: Pull complete
# 2024-10-13T17:20:10: a0f1c015153b: Pull complete
# 2024-10-13T17:20:10: 3b1987910610: Pull complete
# 2024-10-13T17:20:10: Digest: sha256:19edf62d80807b1b49d667d2008b0ad73190ee956c63d497f2603b8448029c6d
# 2024-10-13T17:20:10: Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20240709.v1@sha256:19edf62d80807b1b49d667d2008b0ad73190ee956c63d497f2603b8448029c6d
# 2024-10-13T17:20:10:  ---> ca24c89cac7e
# 2024-10-13T17:20:10: Step 2/17 : USER root
# 2024-10-13T17:20:10:  ---> Running in fa7baa92935f
# 2024-10-13T17:20:11: Removing intermediate container fa7baa92935f
# 2024-10-13T17:20:11:  ---> 6453575d0f58
# 2024-10-13T17:20:11: Step 3/17 : RUN mkdir -p $HOME/.cache
# 2024-10-13T17:20:11:  ---> Running in fc57618923f3
# 2024-10-13T17:20:13: Removing intermediate container fc57618923f3
# 2024-10-13T17:20:13:  ---> 75fa925f9e6b
# 2024-10-13T17:20:13: Step 4/17 : WORKDIR /
# 2024-10-13T17:20:13:  ---> Running in 676940ef2bc6
# 2024-10-13T17:20:14: Removing intermediate container 676940ef2bc6
# 2024-10-13T17:20:14:  ---> 675147e6c196
# 2024-10-13T17:20:14: Step 5/17 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
# 2024-10-13T17:20:15:  ---> 5137d4cf1de9
# 2024-10-13T17:20:15: Step 6/17 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
# 2024-10-13T17:20:15:  ---> Running in 8d111e11f3ac
# 2024-10-13T17:20:17: Removing intermediate container 8d111e11f3ac
# 2024-10-13T17:20:17:  ---> 804c72cd9aee
# 2024-10-13T17:20:17: Step 7/17 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
# 2024-10-13T17:20:18:  ---> 39cda2436bd1
# 2024-10-13T17:20:18: Step 8/17 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_dd93f917fc25913ca45814ef4b23ccd4 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
# 2024-10-13T17:20:18:  ---> Running in 9ab48a6fb120
# 2024-10-13T17:20:19: Retrieving notices: ...working... done
# 2024-10-13T17:20:19: Channels:
# 2024-10-13T17:20:19:  - anaconda
# 2024-10-13T17:20:19:  - conda-forge
# 2024-10-13T17:20:19:  - defaults
# 2024-10-13T17:20:19: Platform: linux-64
# 2024-10-13T17:20:39: Collecting package metadata (repodata.json): ...working... done
# 2024-10-13T17:20:42: Solving environment: ...working... done
# 2024-10-13T17:20:42:
#
# 2024-10-13T17:20:42: ==> WARNING: A newer version of conda exists. <==
# 2024-10-13T17:20:42:     current version: 24.5.0
# 2024-10-13T17:20:42:     latest version: 24.9.1
#
# 2024-10-13T17:20:42: Please update conda by running
#
# 2024-10-13T17:20:42:     $ conda update -n base -c conda-forge conda
#
#
# 2024-10-13T17:20:53:
# 2024-10-13T17:20:53: Downloading and Extracting Packages: ...working... done
# 2024-10-13T17:20:53: Preparing transaction: ...working... done
# 2024-10-13T17:20:56: Verifying transaction: ...working... done
# 2024-10-13T17:20:57: Executing transaction: ...working... done
# 2024-10-13T17:21:36: Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# 2024-10-13T17:21:36: ['/azureml-envs/azureml_dd93f917fc25913ca45814ef4b23ccd4/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.2yuq10yc.requirements.txt', '--exists-action=b']
# 2024-10-13T17:21:36: Pip subprocess output:
# 2024-10-13T17:21:36: Collecting azureml-defaults~=1.57.0 (from -r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading azureml_defaults-1.57.0.post1-py3-none-any.whl.metadata (738 bytes)
# 2024-10-13T17:21:36: Collecting azureml-core~=1.57.0 (from -r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azureml_core-1.57.0.post3-py3-none-any.whl.metadata (3.1 kB)
# 2024-10-13T17:21:36: Collecting azureml-dataprep[fuse] (from -r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading azureml_dataprep-5.2.1-py3-none-any.whl.metadata (2.0 kB)
# 2024-10-13T17:21:36: Collecting azureml-inference-server-http~=1.3 (from azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading azureml_inference_server_http-1.3.3-py3-none-any.whl.metadata (10 kB)
# 2024-10-13T17:21:36: Collecting azureml-dataset-runtime~=1.57.0 (from azureml-dataset-runtime[fuse]~=1.57.0->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading azureml_dataset_runtime-1.57.0-py3-none-any.whl.metadata (1.2 kB)
# 2024-10-13T17:21:36: Collecting pytz (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# 2024-10-13T17:21:36: Collecting backports.tempfile (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading backports.tempfile-1.0-py2.py3-none-any.whl.metadata (2.3 kB)
# 2024-10-13T17:21:36: Collecting pathspec<1.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# 2024-10-13T17:21:36: Collecting requests<3.0.0,>=2.19.1 (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# 2024-10-13T17:21:36: Collecting msal<2.0.0,>=1.15.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading msal-1.31.0-py3-none-any.whl.metadata (11 kB)
# 2024-10-13T17:21:36: Collecting msal-extensions<=2.0.0,>=0.3.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading msal_extensions-1.2.0-py3-none-any.whl.metadata (7.6 kB)
# 2024-10-13T17:21:36: Collecting knack<0.12.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading knack-0.11.0-py3-none-any.whl.metadata (5.2 kB)
# 2024-10-13T17:21:36: Collecting azure-core<2.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
# 2024-10-13T17:21:36: Collecting pkginfo (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading pkginfo-1.11.2-py3-none-any.whl.metadata (11 kB)
# 2024-10-13T17:21:36: Collecting argcomplete<4 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading argcomplete-3.5.1-py3-none-any.whl.metadata (16 kB)
# 2024-10-13T17:21:36: Collecting humanfriendly<11.0,>=4.7 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# 2024-10-13T17:21:36: Collecting paramiko<4.0.0,>=2.0.8 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading paramiko-3.5.0-py3-none-any.whl.metadata (4.4 kB)
# 2024-10-13T17:21:36: Collecting azure-mgmt-resource<=24.0.0,>=15.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azure_mgmt_resource-23.1.1-py3-none-any.whl.metadata (37 kB)
# 2024-10-13T17:21:36: Collecting azure-mgmt-containerregistry<11,>=8.2.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azure_mgmt_containerregistry-10.3.0-py3-none-any.whl.metadata (23 kB)
# 2024-10-13T17:21:36: Collecting azure-mgmt-storage<=22.0.0,>=16.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azure_mgmt_storage-21.2.1-py3-none-any.whl.metadata (31 kB)
# 2024-10-13T17:21:36: Collecting azure-mgmt-keyvault<11.0.0,>=0.40.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azure_mgmt_keyvault-10.3.1-py3-none-any.whl.metadata (15 kB)
# 2024-10-13T17:21:36: Collecting azure-mgmt-authorization<5,>=0.40.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azure_mgmt_authorization-4.0.0-py3-none-any.whl.metadata (18 kB)
# 2024-10-13T17:21:36: Collecting azure-mgmt-network<=26.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azure_mgmt_network-26.0.0-py3-none-any.whl.metadata (84 kB)
# 2024-10-13T17:21:36: Collecting azure-graphrbac<1.0.0,>=0.40.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl.metadata (10 kB)
# 2024-10-13T17:21:36: Collecting azure-common<2.0.0,>=1.1.12 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azure_common-1.1.28-py2.py3-none-any.whl.metadata (5.0 kB)
# 2024-10-13T17:21:36: Collecting msrest<=0.7.1,>=0.5.1 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading msrest-0.7.1-py3-none-any.whl.metadata (21 kB)
# 2024-10-13T17:21:36: Collecting msrestazure<=0.7,>=0.4.33 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading msrestazure-0.6.4.post1-py2.py3-none-any.whl.metadata (15 kB)
# 2024-10-13T17:21:36: Collecting urllib3<3.0.0,>1.26.17 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# 2024-10-13T17:21:36: Collecting packaging<=25.0,>=20.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# 2024-10-13T17:21:36: Collecting python-dateutil<3.0.0,>=2.7.3 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# 2024-10-13T17:21:36: Collecting ndg-httpsclient<=0.5.1 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# 2024-10-13T17:21:36: Collecting SecretStorage<4.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading SecretStorage-3.3.3-py3-none-any.whl.metadata (4.0 kB)
# 2024-10-13T17:21:36: Collecting jsonpickle<4.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading jsonpickle-3.3.0-py3-none-any.whl.metadata (8.3 kB)
# 2024-10-13T17:21:36: Collecting contextlib2<22.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading contextlib2-21.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# 2024-10-13T17:21:36: Collecting docker<8.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# 2024-10-13T17:21:36: Collecting PyJWT<3.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# 2024-10-13T17:21:36: Collecting adal<=1.2.7,>=1.2.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading adal-1.2.7-py2.py3-none-any.whl.metadata (6.9 kB)
# 2024-10-13T17:21:36: Collecting pyopenssl<25.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading pyOpenSSL-24.2.1-py3-none-any.whl.metadata (13 kB)
# 2024-10-13T17:21:36: Collecting jmespath<2.0.0 (from azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# 2024-10-13T17:21:36: Collecting azureml-dataprep-native<42.0.0,>=41.0.0 (from azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading azureml_dataprep_native-41.0.0-cp39-cp39-manylinux1_x86_64.whl.metadata (1.3 kB)
# 2024-10-13T17:21:36: Collecting azureml-dataprep-rslex~=2.23.0dev0 (from azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading azureml_dataprep_rslex-2.23.6-cp39-cp39-manylinux1_x86_64.whl.metadata (1.6 kB)
# 2024-10-13T17:21:36: Collecting cloudpickle<3.0.0,>=1.1.0 (from azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# 2024-10-13T17:21:36: Collecting azure-identity>=1.16.0 (from azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading azure_identity-1.19.0-py3-none-any.whl.metadata (80 kB)
# 2024-10-13T17:21:36: Collecting jsonschema (from azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# 2024-10-13T17:21:36: Collecting pyyaml<7.0.0,>=5.1.0 (from azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading PyYAML-6.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# 2024-10-13T17:21:36: Collecting fusepy<4.0.0,>=3.0.1 (from azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading fusepy-3.0.1.tar.gz (11 kB)
# 2024-10-13T17:21:36:   Preparing metadata (setup.py): started
# 2024-10-13T17:21:36:   Preparing metadata (setup.py): finished with status 'done'
# 2024-10-13T17:21:36: Collecting cryptography>=1.1.0 (from adal<=1.2.7,>=1.2.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading cryptography-43.0.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# 2024-10-13T17:21:36: Collecting six>=1.11.0 (from azure-core<2.0.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# 2024-10-13T17:21:36: Collecting typing-extensions>=4.6.0 (from azure-core<2.0.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# 2024-10-13T17:21:36: Collecting isodate<1.0.0,>=0.6.1 (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# 2024-10-13T17:21:36: Collecting azure-mgmt-core<2.0.0,>=1.3.2 (from azure-mgmt-authorization<5,>=0.40.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading azure_mgmt_core-1.4.0-py3-none-any.whl.metadata (4.1 kB)
# 2024-10-13T17:21:36: INFO: pip is looking at multiple versions of azureml-dataset-runtime to determine which version is compatible with other requirements. This could take a while.
# 2024-10-13T17:21:36: Collecting azureml-dataprep[fuse] (from -r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading azureml_dataprep-5.2.0-py3-none-any.whl.metadata (2.1 kB)
# 2024-10-13T17:21:36:   Downloading azureml_dataprep-5.1.6-py3-none-any.whl.metadata (2.2 kB)
# 2024-10-13T17:21:36: Collecting azureml-dataprep-rslex~=2.22.2dev0 (from azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading azureml_dataprep_rslex-2.22.4-cp39-cp39-manylinux1_x86_64.whl.metadata (1.6 kB)
# 2024-10-13T17:21:36: Collecting pyarrow>=0.17.0 (from azureml-dataset-runtime~=1.57.0->azureml-dataset-runtime[fuse]~=1.57.0->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading pyarrow-17.0.0-cp39-cp39-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# 2024-10-13T17:21:36: Collecting numpy!=1.19.3,<1.24 (from azureml-dataset-runtime~=1.57.0->azureml-dataset-runtime[fuse]~=1.57.0->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading numpy-1.23.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# 2024-10-13T17:21:36: Collecting flask<=2.3.2 (from azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading Flask-2.3.2-py3-none-any.whl.metadata (3.7 kB)
# 2024-10-13T17:21:36: Collecting flask-cors~=5.0.0 (from azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl.metadata (5.5 kB)
# 2024-10-13T17:21:36: Collecting inference-schema~=1.8.0 (from azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading inference_schema-1.8-py3-none-any.whl.metadata (2.5 kB)
# 2024-10-13T17:21:36: Collecting opencensus-ext-azure~=1.1.0 (from azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading opencensus_ext_azure-1.1.13-py2.py3-none-any.whl.metadata (16 kB)
# 2024-10-13T17:21:36: Collecting pydantic~=2.7.1 (from azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading pydantic-2.7.4-py3-none-any.whl.metadata (109 kB)
# 2024-10-13T17:21:36: Collecting pydantic-settings (from azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading pydantic_settings-2.5.2-py3-none-any.whl.metadata (3.5 kB)
# 2024-10-13T17:21:36: Collecting werkzeug>=3.0.3 (from azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading werkzeug-3.0.4-py3-none-any.whl.metadata (3.7 kB)
# 2024-10-13T17:21:36: Collecting certifi>=2024.7.4 (from azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# 2024-10-13T17:21:36: Collecting gunicorn==22.0.0 (from azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading gunicorn-22.0.0-py3-none-any.whl.metadata (4.4 kB)
# 2024-10-13T17:21:36: Collecting pygments (from knack<0.12.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# 2024-10-13T17:21:36: Collecting tabulate (from knack<0.12.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# 2024-10-13T17:21:36: Collecting portalocker<3,>=1.4 (from msal-extensions<=2.0.0,>=0.3.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# 2024-10-13T17:21:36: Collecting requests-oauthlib>=0.5.0 (from msrest<=0.7.1,>=0.5.1->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# 2024-10-13T17:21:36: Collecting pyasn1>=0.1.1 (from ndg-httpsclient<=0.5.1->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# 2024-10-13T17:21:36: Collecting bcrypt>=3.2 (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.6 kB)
# 2024-10-13T17:21:36: Collecting pynacl>=1.5 (from paramiko<4.0.0,>=2.0.8->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# 2024-10-13T17:21:36: Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading charset_normalizer-3.4.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (34 kB)
# 2024-10-13T17:21:36: Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.19.1->requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# 2024-10-13T17:21:36: Collecting PySocks!=1.5.7,>=1.5.6 (from requests[socks]<3.0.0,>=2.19.1->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# 2024-10-13T17:21:36: Collecting jeepney>=0.6 (from SecretStorage<4.0.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading jeepney-0.8.0-py3-none-any.whl.metadata (1.3 kB)
# 2024-10-13T17:21:36: Collecting backports.weakref (from backports.tempfile->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl.metadata (2.3 kB)
# 2024-10-13T17:21:36: Collecting attrs>=22.2.0 (from jsonschema->azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# 2024-10-13T17:21:36: Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# 2024-10-13T17:21:36: Collecting referencing>=0.28.4 (from jsonschema->azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# 2024-10-13T17:21:36: Collecting rpds-py>=0.7.1 (from jsonschema->azureml-dataprep[fuse]->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 3))
# 2024-10-13T17:21:36:   Downloading rpds_py-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# 2024-10-13T17:21:36: Collecting cffi>=1.12 (from cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading cffi-1.17.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# 2024-10-13T17:21:36: Collecting Jinja2>=3.1.2 (from flask<=2.3.2->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# 2024-10-13T17:21:36: Collecting itsdangerous>=2.1.2 (from flask<=2.3.2->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# 2024-10-13T17:21:36: Collecting click>=8.1.3 (from flask<=2.3.2->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# 2024-10-13T17:21:36: Collecting blinker>=1.6.2 (from flask<=2.3.2->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading blinker-1.8.2-py3-none-any.whl.metadata (1.6 kB)
# 2024-10-13T17:21:36: Collecting importlib-metadata>=3.6.0 (from flask<=2.3.2->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# 2024-10-13T17:21:36: Collecting wrapt<=1.16.0,>=1.14.0 (from inference-schema~=1.8.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading wrapt-1.16.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# 2024-10-13T17:21:36: Collecting opencensus<1.0.0,>=0.11.4 (from opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# 2024-10-13T17:21:36: Collecting psutil>=5.6.3 (from opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading psutil-6.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# 2024-10-13T17:21:36: Collecting annotated-types>=0.4.0 (from pydantic~=2.7.1->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# 2024-10-13T17:21:36: Collecting pydantic-core==2.18.4 (from pydantic~=2.7.1->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading pydantic_core-2.18.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# 2024-10-13T17:21:36: Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.5.0->msrest<=0.7.1,>=0.5.1->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# 2024-10-13T17:21:36: Collecting MarkupSafe>=2.1.1 (from werkzeug>=3.0.3->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading MarkupSafe-3.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# 2024-10-13T17:21:36: Collecting python-dotenv>=0.21.0 (from pydantic-settings->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# 2024-10-13T17:21:36: Collecting pycparser (from cffi>=1.12->cryptography>=1.1.0->adal<=1.2.7,>=1.2.0->azureml-core~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 2))
# 2024-10-13T17:21:36:   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# 2024-10-13T17:21:36: Collecting zipp>=3.20 (from importlib-metadata>=3.6.0->flask<=2.3.2->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# 2024-10-13T17:21:36: Collecting opencensus-context>=0.1.3 (from opencensus<1.0.0,>=0.11.4->opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# 2024-10-13T17:21:36: Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus<1.0.0,>=0.11.4->opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading google_api_core-2.21.0-py3-none-any.whl.metadata (2.8 kB)
# 2024-10-13T17:21:36: Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# 2024-10-13T17:21:36: Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading protobuf-5.28.2-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# 2024-10-13T17:21:36: Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# 2024-10-13T17:21:36: Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# 2024-10-13T17:21:36: Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# 2024-10-13T17:21:36: Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# 2024-10-13T17:21:36: Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus<1.0.0,>=0.11.4->opencensus-ext-azure~=1.1.0->azureml-inference-server-http~=1.3->azureml-defaults~=1.57.0->-r /azureml-environment-setup/condaenv.2yuq10yc.requirements.txt (line 1))
# 2024-10-13T17:21:36:   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# 2024-10-13T17:21:36: Downloading azureml_defaults-1.57.0.post1-py3-none-any.whl (2.0 kB)
# 2024-10-13T17:21:36: Downloading azureml_core-1.57.0.post3-py3-none-any.whl (3.3 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 71.6 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading azureml_dataset_runtime-1.57.0-py3-none-any.whl (2.2 kB)
# 2024-10-13T17:21:36: Downloading azureml_dataprep-5.1.6-py3-none-any.whl (252 kB)
# 2024-10-13T17:21:36: Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# 2024-10-13T17:21:36: Downloading argcomplete-3.5.1-py3-none-any.whl (43 kB)
# 2024-10-13T17:21:36: Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# 2024-10-13T17:21:36: Downloading azure_core-1.31.0-py3-none-any.whl (197 kB)
# 2024-10-13T17:21:36: Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# 2024-10-13T17:21:36: Downloading azure_identity-1.19.0-py3-none-any.whl (187 kB)
# 2024-10-13T17:21:36: Downloading azure_mgmt_authorization-4.0.0-py3-none-any.whl (1.1 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 44.7 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading azure_mgmt_containerregistry-10.3.0-py3-none-any.whl (2.3 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 54.9 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading azure_mgmt_keyvault-10.3.1-py3-none-any.whl (901 kB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 901.4/901.4 kB 30.0 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading azure_mgmt_network-26.0.0-py3-none-any.whl (617 kB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.4/617.4 kB 13.9 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading azure_mgmt_resource-23.1.1-py3-none-any.whl (2.6 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 57.4 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading azure_mgmt_storage-21.2.1-py3-none-any.whl (3.2 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 81.6 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading azureml_dataprep_native-41.0.0-cp39-cp39-manylinux1_x86_64.whl (187 kB)
# 2024-10-13T17:21:36: Downloading azureml_dataprep_rslex-2.22.4-cp39-cp39-manylinux1_x86_64.whl (24.8 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 107.9 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading azureml_inference_server_http-1.3.3-py3-none-any.whl (42 kB)
# 2024-10-13T17:21:36: Downloading gunicorn-22.0.0-py3-none-any.whl (84 kB)
# 2024-10-13T17:21:36: Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# 2024-10-13T17:21:36: Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# 2024-10-13T17:21:36: Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# 2024-10-13T17:21:36: Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# 2024-10-13T17:21:36: Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# 2024-10-13T17:21:36: Downloading jsonpickle-3.3.0-py3-none-any.whl (42 kB)
# 2024-10-13T17:21:36: Downloading knack-0.11.0-py3-none-any.whl (60 kB)
# 2024-10-13T17:21:36: Downloading msal-1.31.0-py3-none-any.whl (113 kB)
# 2024-10-13T17:21:36: Downloading msal_extensions-1.2.0-py3-none-any.whl (19 kB)
# 2024-10-13T17:21:36: Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
# 2024-10-13T17:21:36: Downloading msrestazure-0.6.4.post1-py2.py3-none-any.whl (40 kB)
# 2024-10-13T17:21:36: Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# 2024-10-13T17:21:36: Downloading packaging-24.1-py3-none-any.whl (53 kB)
# 2024-10-13T17:21:36: Downloading paramiko-3.5.0-py3-none-any.whl (227 kB)
# 2024-10-13T17:21:36: Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# 2024-10-13T17:21:36: Downloading PyJWT-2.9.0-py3-none-any.whl (22 kB)
# 2024-10-13T17:21:36: Downloading pyOpenSSL-24.2.1-py3-none-any.whl (58 kB)
# 2024-10-13T17:21:36: Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# 2024-10-13T17:21:36: Downloading PyYAML-6.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (737 kB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 kB 24.4 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# 2024-10-13T17:21:36: Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# 2024-10-13T17:21:36: Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# 2024-10-13T17:21:36: Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# 2024-10-13T17:21:36: Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# 2024-10-13T17:21:36: Downloading pkginfo-1.11.2-py3-none-any.whl (31 kB)
# 2024-10-13T17:21:36: Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# 2024-10-13T17:21:36: Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
# 2024-10-13T17:21:36: Downloading azure_mgmt_core-1.4.0-py3-none-any.whl (27 kB)
# 2024-10-13T17:21:36: Downloading bcrypt-4.2.0-cp39-abi3-manylinux_2_28_x86_64.whl (273 kB)
# 2024-10-13T17:21:36: Downloading certifi-2024.8.30-py3-none-any.whl (167 kB)
# 2024-10-13T17:21:36: Downloading charset_normalizer-3.4.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
# 2024-10-13T17:21:36: Downloading cryptography-43.0.1-cp39-abi3-manylinux_2_28_x86_64.whl (4.0 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 99.0 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading Flask-2.3.2-py3-none-any.whl (96 kB)
# 2024-10-13T17:21:36: Downloading Flask_Cors-5.0.0-py2.py3-none-any.whl (14 kB)
# 2024-10-13T17:21:36: Downloading idna-3.10-py3-none-any.whl (70 kB)
# 2024-10-13T17:21:36: Downloading inference_schema-1.8-py3-none-any.whl (21 kB)
# 2024-10-13T17:21:36: Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# 2024-10-13T17:21:36: Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
# 2024-10-13T17:21:36: Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# 2024-10-13T17:21:36: Downloading numpy-1.23.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 98.8 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading opencensus_ext_azure-1.1.13-py2.py3-none-any.whl (43 kB)
# 2024-10-13T17:21:36: Downloading portalocker-2.10.1-py3-none-any.whl (18 kB)
# 2024-10-13T17:21:36: Downloading pyarrow-17.0.0-cp39-cp39-manylinux_2_28_x86_64.whl (39.9 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 84.0 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# 2024-10-13T17:21:36: Downloading pydantic-2.7.4-py3-none-any.whl (409 kB)
# 2024-10-13T17:21:36: Downloading pydantic_core-2.18.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 58.5 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 35.1 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading PySocks-1.7.1-py3-none-any.whl (16 kB)
# 2024-10-13T17:21:36: Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# 2024-10-13T17:21:36: Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# 2024-10-13T17:21:36: Downloading rpds_py-0.20.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (355 kB)
# 2024-10-13T17:21:36: Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# 2024-10-13T17:21:36: Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# 2024-10-13T17:21:36: Downloading werkzeug-3.0.4-py3-none-any.whl (227 kB)
# 2024-10-13T17:21:36: Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# 2024-10-13T17:21:36: Downloading pydantic_settings-2.5.2-py3-none-any.whl (26 kB)
# 2024-10-13T17:21:36: Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
# 2024-10-13T17:21:36:    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.1 MB/s eta 0:00:00
# 2024-10-13T17:21:36: Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# 2024-10-13T17:21:36: Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# 2024-10-13T17:21:36: Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# 2024-10-13T17:21:36: Downloading cffi-1.17.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (445 kB)
# 2024-10-13T17:21:36: Downloading click-8.1.7-py3-none-any.whl (97 kB)
# 2024-10-13T17:21:36: Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# 2024-10-13T17:21:36: Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# 2024-10-13T17:21:36: Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
# 2024-10-13T17:21:36: Downloading MarkupSafe-3.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# 2024-10-13T17:21:36: Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
# 2024-10-13T17:21:36: Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
# ...
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# Ran into a deserialization error. Ignoring since this is failsafe deserialization
# Traceback (most recent call last):
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1509, in failsafe_deserialize
#     return self(target_obj, data, content_type=content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1375, in __call__
#     data = self._unpack_content(response_data, content_type)
#   File "/anaconda/envs/azureml_py38/lib/python3.10/site-packages/msrest/serialization.py", line 1543, in _unpack_content
#     raise ValueError("This pipeline didn't have the RawDeserializer policy; can't deserialize")
# ValueError: This pipeline didn't have the RawDeserializer policy; can't deserialize
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           0
# 2   100.csv           0
# 3    11.csv           1
# 4    12.csv           0
# 5    13.csv           0
# 6    14.csv           1
# 7    15.csv           0
# 8    16.csv           0
# 9    17.csv           1
# 10   18.csv           0
# 11   19.csv           1
# 12    2.csv           1
# 13   20.csv           0
# 14   21.csv           0
# 15   22.csv           0
# 16   23.csv           0
# 17   24.csv           1
# 18   25.csv           1
# 19   26.csv           1

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: 623a5ba2-9305-430d-b021-c2be21512d1a,
# Status: Active,
# Endpoint: https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/69c8f7e5-d34a-43ca-8fc8-17cce3dd848d/resourceGroups/saifahmed.k-rg/providers/Microsoft.MachineLearningServices/workspaces/coursera/PipelineRuns/PipelineSubmit/623a5ba2-9305-430d-b021-c2be21512d1a)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://eastus2.api.azureml.ms/pipelines/v1.0/subscriptions/69c8f7e5-d34a-43ca-8fc8-17cce3dd848d/resourceGroups/saifahmed.k-rg/providers/Microsoft.MachineLearningServices/workspaces/coursera/PipelineRuns/PipelineSubmit/623a5ba2-9305-430d-b021-c2be21512d1a

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# 'f2178d10-1110-4cac-8296-796442c7db39'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: f2178d10-1110-4cac-8296-796442c7db39
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/f2178d10-1110-4cac-8296-796442c7db39?wsid=/subscriptions/69c8f7e5-d34a-43ca-8fc8-17cce3dd848d/resourcegroups/saifahmed.k-rg/workspaces/coursera&tid=44f1ecac-984f-479a-8b55-63bb294261f6
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: f2103c51-ffbc-48bb-b50b-1ff3f100c390
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/f2103c51-ffbc-48bb-b50b-1ff3f100c390?wsid=/subscriptions/69c8f7e5-d34a-43ca-8fc8-17cce3dd848d/resourcegroups/saifahmed.k-rg/workspaces/coursera&tid=44f1ecac-984f-479a-8b55-63bb294261f6
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': 'f2103c51-ffbc-48bb-b50b-1ff3f100c390', 'target': 'your-compute-cluster', 'status': 'Completed', 'startTimeUtc': '2024-10-13T17:30:23.186823Z', 'endTimeUtc': '2024-10-13T17:30:23.186823Z', 'services': {}, 'properties': {'azureml.isreused': 'true', 'azureml.reusedrunid': '51e79426-47cb-473b-aef9-bc8f1c2f6b8e', 'azureml.reusednodeid': '202486e3', 'azureml.reusedpipeline': '58abc9c3-6dd9-4a02-a4cd-eeb6d2369615', 'azureml.reusedpipelinerunid': '58abc9c3-6dd9-4a02-a4cd-eeb6d2369615', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '202486e3', 'ContentSnapshotId': 'fa4fa06c-ea00-49ad-a03a-bd89e96dffeb', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '8de0a783-7cf8-4d94-898c-3c52cf15ec81', 'azureml.moduleFamilyId': 'b25bea5f-951f-44af-ad64-96e270869d19', 'azureml.moduleName': 'batch-score-diabetes', 'azureml.pipeline': 'f2178d10-1110-4cac-8296-796442c7db39', 'azureml.pipelinerunid': 'f2178d10-1110-4cac-8296-796442c7db39', 'azureml.pipelineid': '623a5ba2-9305-430d-b021-c2be21512d1a', 'azureml.rootpipelinerunid': '58abc9c3-6dd9-4a02-a4cd-eeb6d2369615', 'azureml.pipelineComponent': 'masterescloud', 'azureml.prsdriver.version': 'v1', 'azureml.prsdriver.snapshotcreator': 'collie', 'azureml.parallelrunstep': 'true', 'azureml.prs.passcollie': 'true', 'azureml.collieComponent': 'collie-eastus2', 'CollieRunType': 'Collie.ParentRun', 'azureml.collieJobType': 'Legacy', '_azureml.ComputeTargetType': 'amlctrain', '_azureml.ClusterName': 'your-compute-cluster', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '1d4a0f4e-1ea5-4f70-b763-ada81635b78b'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.57.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'ParallelTask', 'target': 'your-compute-cluster', 'dataReferences': {'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/51e79426-47cb-473b-aef9-bc8f1c2f6b8e/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '1d4a0f4e-1ea5-4f70-b763-ada81635b78b', 'name': None, 'version': '1'}, 'dataPath': None, 'uri': None, 'type': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'batch_environment', 'version': 'Autosave_2024-10-13T17:16:19Z_57532b0b', 'assetId': 'azureml://locations/eastus2/workspaces/fbff0866-df0b-44e6-ad41-a794abec9d1a/environments/batch_environment/versions/Autosave_2024-10-13T17:16:19Z_57532b0b', 'autoRebuild': True, 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'name': 'project_environment', 'dependencies': ['python=3.9.12', {'pip': ['azureml-defaults~=1.57.0', 'azureml-core~=1.57.0', 'azureml-dataprep[fuse]']}, 'scikit-learn', 'pip'], 'channels': ['anaconda', 'conda-forge']}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi4.1.0-ubuntu20.04:20240709.v1', 'platform': {'os': 'Linux', 'architecture': 'amd6 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'f2178d10-1110-4cac-8296-796442c7db39', 'status': 'Completed', 'startTimeUtc': '2024-10-13T17:30:22.622004Z', 'endTimeUtc': '2024-10-13T17:30:24.219956Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineid': '623a5ba2-9305-430d-b021-c2be21512d1a', 'azureml.pipelineComponent': 'pipelinerun', 'azureml.pipelines.stages': '{"Initialization":null,"Execution":{"StartTime":"2024-10-13T17:30:22.8995007+00:00","EndTime":"2024-10-13T17:30:24.0744654+00:00","Status":"Finished"}}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://coursera1546744657.blob.core.windows.net/azureml/ExperimentRun/dcid.f2178d10-1110-4cac-8296-796442c7db39/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=weoSCPfEqxKOHiPCxhmUzo%2BJiK%2BmpTv6ukvABG8E3aM%3D&skoid=a0663b13-76d9-4a7b-bd33-d1f25a0d4d07&sktid=44f1ecac-984f-479a-8b55-63bb294261f6&skt=2024-10-13T10%3A55%3A02Z&ske=2024-10-15T11%3A05%3A02Z&sks=b&skv=2019-07-07&st=2024-10-13T17%3A20%3A26Z&se=2024-10-14T01%3A30%3A26Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://coursera1546744657.blob.core.windows.net/azureml/ExperimentRun/dcid.f2178d10-1110-4cac-8296-796442c7db39/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=XeehuVvpJ1nhlCgA9OxI0bbIQnl2X5irjacltODCdHU%3D&skoid=a0663b13-76d9-4a7b-bd33-d1f25a0d4d07&sktid=44f1ecac-984f-479a-8b55-63bb294261f6&skt=2024-10-13T10%3A55%3A02Z&ske=2024-10-15T11%3A05%3A02Z&sks=b&skv=2019-07-07&st=2024-10-13T17%3A20%3A26Z&se=2024-10-14T01%3A30%3A26Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://coursera1546744657.blob.core.windows.net/azureml/ExperimentRun/dcid.f2178d10-1110-4cac-8296-796442c7db39/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=6Rg5KMgsR3bu1gkbgXvnRNDnGKBr9F40cRnUvUgWAJ4%3D&skoid=a0663b13-76d9-4a7b-bd33-d1f25a0d4d07&sktid=44f1ecac-984f-479a-8b55-63bb294261f6&skt=2024-10-13T10%3A55%3A02Z&ske=2024-10-15T11%3A05%3A02Z&sks=b&skv=2019-07-07&st=2024-10-13T17%3A20%3A26Z&se=2024-10-14T01%3A30%3A26Z&sp=r'}, 'submittedBy': 'Saif Ahmed Khaja'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     1.csv           0
# 1    10.csv           0
# 2   100.csv           0
# 3    11.csv           1
# 4    12.csv           0
# 5    13.csv           0
# 6    14.csv           1
# 7    15.csv           0
# 8    16.csv           0
# 9    17.csv           1
# 10   18.csv           0
# 11   19.csv           1
# 12    2.csv           1
# 13   20.csv           0
# 14   21.csv           0
# 15   22.csv           0
# 16   23.csv           0
# 17   24.csv           1
# 18   25.csv           1
# 19   26.csv           1

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
